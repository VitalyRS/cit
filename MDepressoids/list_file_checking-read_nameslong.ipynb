# %%
import pandas as pd

# %%
bd=pd.read_csv("depression.txt")
names=pd.read_csv("names_long.csv")

# %%
i=0
fnames=[]
for nn in names.names:
    if len(nn)<50:
      #  print nn,i
        fnames.append(nn)
        i=i+1
fnames
# Out:
# ['0523FMRI_SHASHOVA_A__M',
#  "0524FMRI-EEG_MEL'NIKOV_M__E",
#  "0526FMRI-EEG_BEZMATERNY'X_D__D",
#  '0527FMRI-EEG_EFREMOV_B_O',
#  '0530FMRI-EEG_ZARIPOVA_D_I',
#  "0532FMRI-EEG_SARY'GINA_S_A",
#  '0537FMRI-EEG_SHAPOSHNIKOV_A_V',
#  '0540FMRI-EEG_KALACHINA_E_A',
#  '0541FMRI-EEG_CHUGAINOV_A_N',
#  '0543FMRI-EEG_KOSTYUSHINA_E_F',
#  '0544FMRI-EEG_VASILIEVA_A_V',
#  '0547FMRI-EEG_MIKHALEVA_A_S',
#  '0548FMRI-EEG_GERMAN_D_O',
#  '0549FMRI-EEG_POKROVSKIY_M_A',
#  '0550FMRI-EEG_KRAYNYAK_V_V',
#  '0551FMRI-EEG_KAIRBEKOV_A_M',
#  '0552FMRI-EEG_SHELUDYAKOVA_S_A',
#  '0553FMRI-EEG_ALESENKO_M_I',
#  '0554FMRI-EEG_BOGOMOLOV_I_P',
#  '0555FMRI-EEG_BUTSAN_N_V',
#  '0556FMRI-EEG_BAEVA_A_V',
#  '0557FMRI-EEG_ZELENSKAYA_E_M',
#  '0558FMRI-EEG_YAKOVLEV_V_I',
#  "0559FMRI-EEG_PNE'VA_I__A",
#  "0560FMRI-EEG_FAT'JANOVA_A__A",
#  '0562FMRI-EEG_IKONNIKOV_V_V',
#  '0563FMRI-EEG_MELIKHOVA_YU_V',
#  '0567FMRI-EEG_XOMIK_V_V',
#  '0586FMRI-EEG_VAXMISTROVA_L__V',
#  '0589FMRI-EEG_SVIRIDOVA_YU_O',
# ...

# %%
import re
nnum,nnam=[],[]
for nn in fnames:
    pattern1=u"\d+"
    pattern2=u"\_\D*\_"
    nnum.append(re.findall(pattern1,nn)[0])
    nnam.append(re.findall(pattern2,nn)[0][1:-1])
    
datas={"num":nnum, "name":nnam, "nameb":fnames}
bfolders=pd.DataFrame(datas)
bfolders
# Out:
#                 name                            nameb   num
# 0        SHASHOVA_A_           0523FMRI_SHASHOVA_A__M  0523
# 1       MEL'NIKOV_M_      0524FMRI-EEG_MEL'NIKOV_M__E  0524
# 2    BEZMATERNY'X_D_   0526FMRI-EEG_BEZMATERNY'X_D__D  0526
# 3          EFREMOV_B         0527FMRI-EEG_EFREMOV_B_O  0527
# 4         ZARIPOVA_D        0530FMRI-EEG_ZARIPOVA_D_I  0530
# 5        SARY'GINA_S       0532FMRI-EEG_SARY'GINA_S_A  0532
# 6     SHAPOSHNIKOV_A    0537FMRI-EEG_SHAPOSHNIKOV_A_V  0537
# 7        KALACHINA_E       0540FMRI-EEG_KALACHINA_E_A  0540
# 8        CHUGAINOV_A       0541FMRI-EEG_CHUGAINOV_A_N  0541
# 9      KOSTYUSHINA_E     0543FMRI-EEG_KOSTYUSHINA_E_F  0543
# 10       VASILIEVA_A       0544FMRI-EEG_VASILIEVA_A_V  0544
# 11       MIKHALEVA_A       0547FMRI-EEG_MIKHALEVA_A_S  0547
# 12          GERMAN_D          0548FMRI-EEG_GERMAN_D_O  0548
# 13      POKROVSKIY_M      0549FMRI-EEG_POKROVSKIY_M_A  0549
# 14        KRAYNYAK_V        0550FMRI-EEG_KRAYNYAK_V_V  0550
# ...

# %%
patternD=u"\d+_\d+"
patternDD=u"\d+"
lll1,lll2,lll3,lll4,lll5=[],[],[],[],[]
for nama,nima in zip(bfolders.name,bfolders.num):
    i=0
    for nn in names.names:
        
        if nama in nn:
            if "LONG" in nn:
                figa=re.findall(patternD,nn)[0]
                print figa
                figaD=re.findall(patternDD,figa)
                print nama,i,figaD[0],figaD[1],nima
                lll1.append(nama)
                lll2.append(i)
                lll3.append(figaD[0])
                lll4.append(figaD[1])
                lll5.append(nima)
                i=i+1
datas={"lim1":lll1,"lim2":lll2,"lim3":lll3,"lim4":lll4,"lim5":lll5}                
BAGAGA=pd.DataFrame(datas)
BAGAGA.head()
# Out:
# 506833672_301
# MEL'NIKOV_M_ 0 506833672 301 0524
# 506833672_401
# MEL'NIKOV_M_ 1 506833672 401 0524
# 506833672_501
# MEL'NIKOV_M_ 2 506833672 501 0524
# 506833672_601
# MEL'NIKOV_M_ 3 506833672 601 0524
# 507199628_301
# BEZMATERNY'X_D_ 0 507199628 301 0526
# 507199628_401
# BEZMATERNY'X_D_ 1 507199628 401 0526
# 507199628_501
# BEZMATERNY'X_D_ 2 507199628 501 0526
# 507199628_601
# BEZMATERNY'X_D_ 3 507199628 601 0526
# 507199628_701
# BEZMATERNY'X_D_ 4 507199628 701 0526
# 507281850_301
# EFREMOV_B 0 507281850 301 0527
# 507281850_401
# EFREMOV_B 1 507281850 401 0527
# 507281850_501
# EFREMOV_B 2 507281850 501 0527
# 505293918_301
# ZARIPOVA_D 0 505293918 301 0530
# 505293918_501
# ZARIPOVA_D 1 505293918 501 0530
# 505293918_601
# ZARIPOVA_D 2 505293918 601 0530
# 505293918_701
# ZARIPOVA_D 3 505293918 701 0530
# 505293918_801
# ZARIPOVA_D 4 505293918 801 0530
# 506248311_601
# SARY'GINA_S 0 506248311 601 0532
# 506248311_701
# SARY'GINA_S 1 506248311 701 0532
# 506248311_801
# ...

# %%
for lim3,lim4,lim5 in zip(BAGAGA.lim3,BAGAGA.lim4,BAGAGA.lim5):
    print lim3,lim4,lim5
# Out:
# 506833672 301 0524
# 506833672 401 0524
# 506833672 501 0524
# 506833672 601 0524
# 507199628 301 0526
# 507199628 401 0526
# 507199628 501 0526
# 507199628 601 0526
# 507199628 701 0526
# 507281850 301 0527
# 507281850 401 0527
# 507281850 501 0527
# 505293918 301 0530
# 505293918 501 0530
# 505293918 601 0530
# 505293918 701 0530
# 505293918 801 0530
# 506248311 601 0532
# 506248311 701 0532
# 506248311 801 0532
# 506930685 1001 0537
# 506930685 601 0537
# 506930685 701 0537
# 506930685 801 0537
# 506930685 901 0537
# 537592221 501 0537
# 537592221 601 0537
# 537592221 701 0537
# 507183005 601 0540
# 507183005 701 0540
# 507183005 801 0540
# 504930339 1101 0541
# 504930339 1201 0541
# 504930339 1301 0541
# 504930339 1401 0541
# 504930339 601 0541
# 504930339 701 0541
# 504930339 801 0541
# 504930339 901 0541
# 505031502 601 0543
# 505031502 701 0543
# 505031502 801 0543
# 505195650 601 0544
# 505195650 701 0544
# 505195650 801 0544
# 537851093 501 0544
# 537851093 601 0544
# ...

# %%
W1=""
Num1="0633"
Num2="537851093"
Num3="601"
 
#537851093 601 0633 
if len (W1)==0:
    pat1="\A"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
elif W1=="a":
    pat1="\Aa"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
elif W1=="wa":
    pat1="\Awa"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
elif W1=="swa":
    pat1="\Aswa"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
else:
    pat1=W1+"\w*"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
t=0
zz=[]
for i in bd.iloc[:].values:
    fina=re.findall(pat1,i[0])
    if len(fina)!=0:
        print fina,t
        zz.append(fina[0])
        t=t+1
len(set(zz))
#220 +219+219+219
# Out:
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_001.nii'] 0
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_002.nii'] 1
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_003.nii'] 2
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_004.nii'] 3
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_005.nii'] 4
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_006.nii'] 5
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_007.nii'] 6
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_008.nii'] 7
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_009.nii'] 8
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_010.nii'] 9
# ['0633FMRI-EEG_20170120_537851093_601_EPI_25x5_LONG_SENSE_EPI_25x5_LONG_011.nii'] 10
# ...

# %%
def count_files(W1,Num1,Num2,Num3,bd):
    #W1="swa"
    #Num1="0537"
    #Num2="506930685"
    #Num3="1001"
    if len (W1)==0:
        pat1="\A"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
    elif W1=="a":
        pat1="\Aa"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
    elif W1=="wa":
        pat1="\Awa"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
    elif W1=="swa":
        pat1="\Aswa"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"
    else:
        pat1=W1+"\w*"+Num1+"\w*\W*-\w*\W*"+Num2+"\w*\W*" +    Num3  + "\w*\W*LONG\w*\W*.nii"

    zz=[]
    for i in bd.iloc[:].values:
        fina=re.findall(pat1,i[0])
        if len(fina)!=0:
        #    print fina,t
            zz.append(fina[0])
    return len(set(zz))

def count_conw1(Num1,Num2,Num3,bd):
    W1=""
    c1= count_files(W1,Num1,Num2,Num3,bd)
    W1="a"
    c2= count_files(W1,Num1,Num2,Num3,bd)
    W1="wa"
    c3= count_files(W1,Num1,Num2,Num3,bd)
    W1="swa"
    c4= count_files(W1,Num1,Num2,Num3,bd)
    return c1,c2,c3,c4
Num1="0537"
Num2="506930685"
Num3="1001"
 #"506838986 801 0610
Num1="0610"
Num2="506838986"
Num3="801"

ll1,ll2,ll3,ll4,cc1,cc2,cc3,cc4=[],[],[],[],[],[],[],[]
for lim3,lim4,lim5 in zip(BAGAGA.lim3,BAGAGA.lim4,BAGAGA.lim5):
    Num2=lim3
    Num3=lim4
    Num1=lim5
    c1,c2,c3,c4=count_conw1(Num1,Num2,Num3,bd)
    print lim3,lim4,lim5, c1,c2,c3,c4
    ll1.append(lim3)
    ll2.append(lim4)
    ll3.append(lim5)
    cc1.append(c1)
    cc2.append(c2)
    cc3.append(c3)
    cc4.append(c4)
datka={"b_num":ll1,"long_num":ll2,"id_num":ll3,"file_n":cc1,"file_a":cc2,"file_wa":cc3,"file_swa":cc4}
BDRESUME=pd.DataFrame(datka)
BDRESUME.head()
# Out:
# 506833672 301 0524 42 41 41 41
# 506833672 401 0524 346 345 345 345
# 506833672 501 0524 389 388 388 388
# 506833672 601 0524 408 407 407 407
# 507199628 301 0526 188 187 187 187
# 507199628 401 0526 204 203 203 203
# 507199628 501 0526 52 51 51 51
# 507199628 601 0526 123 122 122 122
# 507199628 701 0526 215 214 214 214
# 507281850 301 0527 185 184 184 184
# 507281850 401 0527 199 198 198 198
# 507281850 501 0527 258 257 257 257
# 505293918 301 0530 101 100 100 100
# 505293918 501 0530 51 50 50 50
# 505293918 601 0530 51 50 50 50
# 505293918 701 0530 21 20 20 20
# 505293918 801 0530 204 203 203 203
# 506248311 601 0532 203 202 202 202
# 506248311 701 0532 205 204 204 204
# 506248311 801 0532 240 239 239 239
# 506930685 1001 0537 238 237 237 237
# 506930685 601 0537 27 26 26 26
# 506930685 701 0537 92 91 91 91
# 506930685 801 0537 202 201 201 201
# 506930685 901 0537 203 202 202 202
# 537592221 501 0537 0 0 0 0
# 537592221 601 0537 0 0 0 0
# 537592221 701 0537 0 0 0 0
# ...

# %%
#nba=BDRESUME[BDRESUME.file_swa>150]
nba=BDRESUME
nba.index=range(nba.shape[0])
Tower_num=list(set(nba.id_num))
R1=["0549","0567","0590","0592","0551","0586","0555","0537","0548","0594",
"0563","0556","0544","0559","0597","0541","0600","0599","0553","0552",
"0589","0598","0606","0614","0608","0591","0612","0611","0613","0554","0610",
"0557","0593","0601","0605","0532","0543","0547","0550","0560","0595","0596"]

R2=["0620","0621","0622","0623","0624","0625","0626","0627","0628","0629","0630","0632","0633",
"0634","0635","0636","0637","0638","0639","0640","0641","0642","0643","0644","0645","0646",
"0647","0648","0649","0650","0651","0652","0656","0657","0658"]
import numpy as np
np.setdiff1d( Tower_num,R1)
ALL_NUM=[]
ALL_NUM.extend(Tower_num)
ALL_NUM.extend(R1)
ALL_NUM.extend(R2)
all_num=list(set(ALL_NUM))
all_num.sort()
tp=[]
tptow=[]
for num in all_num:
    if num in R1:
        tp.append(1)
    elif num in R2:
        tp.append(2)
    else :
        tp.append(0)
    if num in Tower_num:
        tptow.append(1)
    else:
        tptow.append(0)
zip(all_num,tp,tptow)
datka={"id_num":all_num,"R1R2":tp,"TowY":tptow}
BD_ALL=pd.DataFrame(datka)
BD_ALL_NOL=BD_ALL[BD_ALL.R1R2!=0]
BD_ALL_NOL.index=range(BD_ALL_NOL.shape[0])
BD_ALL_NOL.head()
# 	b_num 	file_a 	file_n 	file_swa 	file_wa 	id_num 	long_num
BDRESUME.head()#id_num
# Out:
#        b_num  file_a  file_n  file_swa  file_wa id_num long_num
# 0  506833672      41      42        41       41   0524      301
# 1  506833672     345     346       345      345   0524      401
# 2  506833672     388     389       388      388   0524      501
# 3  506833672     407     408       407      407   0524      601
# 4  507199628     187     188       187      187   0526      301

# %%
BD_ALL_NOL.head()
# Out:
#    R1R2  TowY id_num
# 0     1     1   0532
# 1     1     1   0537
# 2     1     1   0541
# 3     1     1   0543
# 4     1     1   0544

# %%
addm=[]
LIMIT_SCANS=150
mma=[]
smma=[]
for id_num in BD_ALL_NOL.id_num[:]:
    
    lbd=BDRESUME[BDRESUME.id_num==id_num]
    adm=np.vstack((lbd.long_num.values,lbd.file_swa.values))
    mma.append(adm.shape[1])
    smma.append(sum(adm[1,:]>LIMIT_SCANS))
    addm.append(adm)
    #print adm
lbd    
BD_ALL_NOL["ARR"]=addm
BD_ALL_NOL["MMA"]=mma
BD_ALL_NOL["SMMA"]=smma
BD_ALL_NOL
# Out:
# /home/vitaly/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vitaly/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vitaly/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
BD_ALL_NOL[BD_ALL_NOL.SMMA<3]
# Out:
#     R1R2  TowY id_num                                               ARR  MMA  \
# 54     2     1   0633  [[601, 701, 801, 501, 601], [0, 0, 0, 195, 219]]    5
# 55     2     0   0634                                          [[], []]    0
# 56     2     0   0635                                          [[], []]    0
# 57     2     0   0636                                          [[], []]    0
# 58     2     0   0637                                          [[], []]    0
# 59     2     0   0638                                          [[], []]    0
# 60     2     0   0639                                          [[], []]    0
# 61     2     0   0640                                          [[], []]    0
# 62     2     0   0641                                          [[], []]    0
# 63     2     0   0642                                          [[], []]    0
# 64     2     0   0643                                          [[], []]    0
# ...
