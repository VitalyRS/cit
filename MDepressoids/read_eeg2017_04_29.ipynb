# %%
import pandas as pd


"""folder :/u/eeg-fmri/depression/eeg$ ls
data="2017_04_29"
depression  depression2  depression_obrab"""

files_dep_eeg01="dep_eeg_2017_04_29.txt"
files_dep_eeg02="dep2_eeg_2017_04_29.txt"

bd1=pd.read_csv(files_dep_eeg01)
bd2=pd.read_csv(files_dep_eeg02)
bd1.head()
# Out:
#                        .:
# 0     Bezm 30_08_2016.eeg
# 1    Bezm 30_08_2016.vhdr
# 2    Bezm 30_08_2016.vmrk
# 3   Bezm 30_08_2016_2.eeg
# 4  Bezm 30_08_2016_2.vhdr

# %%
#gr2_Pneva_20_01_2017_fon.eeg
#gr2_Pneva_20_01_2017_fon.vhdr
#gr2_Pneva_20_01_2017_fon.vmrk
#gr2_Pneva_20_01_2017_t1.eeg
#gr2_Pneva_20_01_2017_t1.vhdr
#gr2_Pneva_20_01_2017_t1.vmrk
#gr2_Pneva_20_01_2017_t2.eeg
#gr2_Pneva_20_01_2017_t2.vhdr
#gr2_Pneva_20_01_2017_t2.vmrk
#gr2_Pneva_20_01_2017_t3.eeg
#gr2_Pneva_20_01_2017_t3.vhdr
#gr2_Pneva_20_01_2017_t3.vmrk
import re


"""for i in range(bd1.shape[0]):
    st1=bd1.iloc[i,:].values[0]
    
    
    ex_St1=re.findall(pattern1,st1)
    ex_St2=re.findall(pattern2,st1)
    if len(ex_St1)>0:
        if len(ex_St1[0])>2:
            print st1,ex_St1[0],ex_St2[0]"""

st1="gr2_Pneva_20_01_2017_t3.vmrk"
pattern1=u"_\D*"
pattern2=u"\gr\d*"
pattern3=u"t\d"
pattern4=u"\.\D*"
pattern5=u"_\d+_\d+_\d+"
print re.findall(pattern1,st1)
print  re.findall(pattern2,st1)
print re.findall(pattern3,st1)
print  re.findall(pattern4,st1)
print  re.findall(pattern5,st1)
# Out:
# ['_Pneva_', '_', '_', '_t']
# ['gr2']
# ['t3']
# ['.vmrk']
# ['_20_01_2017']

# %%
pattern1=u"_\D*"
pattern2=u"\gr\d*"
pattern3=u"t\d"
pattern4=u"\.\D*"
pattern5=u"\d+_\d+_\d+"

for i in range(bd2.shape[0]):
    st1=bd2.iloc[i,:].values[0]
    
    
    ex_St1=re.findall(pattern1,st1)
    ex_St2=re.findall(pattern2,st1)
    ex_St3=re.findall(pattern3,st1)
    ex_St4=re.findall(pattern4,st1)
    ex_St5=re.findall(pattern5,st1)
    if len(ex_St1)>0:
        if len(ex_St1[0])>2:
            print st1,ex_St1[0],ex_St2,ex_St3,ex_St4,ex_St5
# Out:
# dep2_eeg_2017_04_29.txt _eeg_ [] [] ['.txt'] ['2017_04_29']
# gr2_Alesenko_27_01_2017_fon.eeg _Alesenko_ ['gr2'] [] ['.eeg'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_fon.vhdr _Alesenko_ ['gr2'] [] ['.vhdr'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_fon.vmrk _Alesenko_ ['gr2'] [] ['.vmrk'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t.eeg _Alesenko_ ['gr2'] [] ['.eeg'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t.vhdr _Alesenko_ ['gr2'] [] ['.vhdr'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t.vmrk _Alesenko_ ['gr2'] [] ['.vmrk'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t1.eeg _Alesenko_ ['gr2'] ['t1'] ['.eeg'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t1.vhdr _Alesenko_ ['gr2'] ['t1'] ['.vhdr'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t1.vmrk _Alesenko_ ['gr2'] ['t1'] ['.vmrk'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t2.eeg _Alesenko_ ['gr2'] ['t2'] ['.eeg'] ['27_01_2017']
# gr2_Alesenko_27_01_2017_t2.vhdr _Alesenko_ ['gr2'] ['t2'] ['.vhdr'] ['27_01_2017']
# ...
