# %%
import pandas as pd
import os
import re
import math
import numpy as np
def get_fmri_id_name(stra):
    pattern_fmri_id=u"\d+"
    pattern_fmri_name=u"_\D+"

    if isinstance(stra, basestring):
        #print re.findall(pattern_fmri_id,stra)[0]
        #print re.findall(pattern_fmri_name,stra)[0]
        return re.findall(pattern_fmri_id,stra)[0],re.findall(pattern_fmri_name,stra)[0][1:]
    else:
        return  "none","none"

# %%
file_fmri_all="fmri_all_14_05_2017.csv"
file_fmri_folder="fmri_folder_14_05_2017.csv"
file_person="fmri_persons.csv"

# %%
bd_person=pd.read_csv(file_person,sep="\t")
bd_person.head()
iid,nname=[],[]

for stra in bd_person.iloc[:,0]:
    ida,name= get_fmri_id_name(stra)
    iid.append(ida)
    nname.append(name)
for stra in bd_person.iloc[:,1]:
    ida,name= get_fmri_id_name(stra)
    iid.append(ida)
    nname.append(name)

datas={"id":iid,"name":nname}
bd_person_re=pd.DataFrame(datas)
bd_person_re.head(10)
# Out:
#      id              name
# 0  0532     SARY'GINA_S_A
# 1  0537  SHAPOSHNIKOV_A_V
# 2  0541     CHUGAINOV_A_N
# 3  0543   KOSTYUSHINA_E_F
# 4  0544     VASILIEVA_A_V
# 5  0547     MIKHALEVA_A_S
# 6  0548        GERMAN_D_O
# 7  0549    POKROVSKIY_M_A
# 8  0550      KRAYNYAK_V_V
# 9  0551     KAIRBEKOV_A_M

# %%
bd_fmri_all=pd.read_csv(file_fmri_all,sep="\t")

bd_fmri_all.head(10)
# Out:
#                                .:
# 0          0523FMRI_SHASHOVA_A__M
# 1     0524FMRI-EEG_MEL'NIKOV_M__E
# 2  0526FMRI-EEG_BEZMATERNY'X_D__D
# 3        0527FMRI-EEG_EFREMOV_B_O
# 4       0530FMRI-EEG_ZARIPOVA_D_I
# 5      0532FMRI-EEG_SARY'GINA_S_A
# 6   0537FMRI-EEG_SHAPOSHNIKOV_A_V
# 7      0540FMRI-EEG_KALACHINA_E_A
# 8      0541FMRI-EEG_CHUGAINOV_A_N
# 9    0543FMRI-EEG_KOSTYUSHINA_E_F

# %%
def get_long(IDA,TYPE,bd_fmri_all):
    rres=[]
    for sta in bd_fmri_all.iloc[:,0]:
        patternLONG=u"\A"+TYPE+IDA+"\S*_LONG\S*\.nii"
        res=re.findall(patternLONG,sta)
        if len(res)!=0:
            res=res[0]
            rres.append(res)
    aaa=[]
    for sta in rres:
        patternFOL=u"_\d{3,4}_"         # *_FE_EPI
        res=re.findall(patternFOL,sta)
        if len(res)!=0:
            aa=res[0][1:-1]
            aaa.append(aa)
    unique, counts = np.unique(aaa, return_counts=True)
    return unique,counts

def get_50(IDA,TYPE,bd_fmri_all):
    rres=[]
    for sta in bd_fmri_all.iloc[:,0]:
#    print sta
        pattern50=u"\A"+TYPE+IDA+"\S*25x5x50\S*\.nii"
        res=re.findall(pattern50,sta)
    
        if len(res)!=0:
            res=res[0]
            rres.append(res)
        #print res
    aaa=[]
    for sta in rres:
        patternFOL=u"_\d{3,4}_"         # *_FE_EPI
        res=re.findall(patternFOL,sta)
        if len(res)!=0:
            aa=res[0][1:-1]
            aaa.append(aa)

    unique, counts = np.unique(aaa, return_counts=True)
    return unique,counts


def get_100(IDA,TYPE,bd_fmri_all):
    rres=[]
    for sta in bd_fmri_all.iloc[:,0]:

        pattern100=u"\A"+TYPE+IDA+"\S*25x5x100\S*\.nii"
        res=re.findall(pattern100,sta)
        if len(res)!=0:
            res=res[0]
            rres.append(res)
    aaa=[]
    for sta in rres:
        patternFOL=u"_\d{3,4}_"         # *_FE_EPI
        res=re.findall(patternFOL,sta)
        if len(res)!=0:
            aa=res[0][1:-1]
            aaa.append(aa)
    unique, counts = np.unique(aaa, return_counts=True)
    return unique,counts

# %%
import time
for IDA in bd_person_re.id:
    TYPE=""
    #IDA="0644"
    print "********************"
    print IDA, TYPE
    print "long",get_long(IDA,TYPE,bd_fmri_all)
    print "50",get_50(IDA,TYPE,bd_fmri_all)
    print  "100",get_100(IDA,TYPE,bd_fmri_all)
    time.sleep(3)

for IDA in bd_person_re.id:
    TYPE="wa"
    #IDA="0644"
    print "********************"
    print IDA, TYPE
    print "long",get_long(IDA,TYPE,bd_fmri_all)
    print "50",get_50(IDA,TYPE,bd_fmri_all)
    print  "100",get_100(IDA,TYPE,bd_fmri_all)
    time.sleep(3)
    
for IDA in bd_person_re.id:
    TYPE="swa"
    #IDA="0644"
    print "********************"
    print IDA, TYPE
    print "long",get_long(IDA,TYPE,bd_fmri_all)
    print "50",get_50(IDA,TYPE,bd_fmri_all)
    print  "100",get_100(IDA,TYPE,bd_fmri_all)
    time.sleep(3)
# Out:
#  ********************
# 0532
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([203, 205, 240]))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0537
# long (array(['1001', '601', '701', '801', '901'],
#       dtype='|S4'), array([238,  27,  92, 202, 203]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0541
# long (array(['1101', '1201', '1301', '1401', '601', '701', '801', '901'],
#       dtype='|S4'), array([202, 227, 268,  21,  22,  11,   6,  46]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0543
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([199, 248, 295]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0544
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([210, 227, 250]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0547
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([200, 207, 234]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0548
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([242, 232, 282]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0549
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([186, 191, 226]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0550
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([233, 246, 349]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0551
# long (array(['1001', '601', '701', '801', '901'],
#       dtype='|S4'), array([248,   1,   1, 193, 221]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0552
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([207, 220, 276]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0553
# long (array(['301', '401', '501', '601', '701', '801'],
#       dtype='|S3'), array([100,  51,  51, 231, 237, 269]))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0554
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([217, 226, 263]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['401'],
#       dtype='|S3'), array([100]))
# ********************
# 0555
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([201, 220, 241]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0556
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([213, 217, 256]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0557
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([207, 234, 260]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0559
# long (array(['601', '701', '801', '901'],
#       dtype='|S3'), array([193,  17, 205, 235]))
# 50 (array(['401'],
#       dtype='|S3'), array([50]))
# 100 (array(['301', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0560
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([226, 273, 317]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0563
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([190, 206, 237]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0567
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([200, 203, 213]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0586
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([196, 204, 243]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0589
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([190, 205, 236]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0590
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([195, 211, 234]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0591
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([208, 211, 235]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0592
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([213, 214, 241]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0593
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 210, 229]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0594
# long (array(['501', '601', '701', '801'],
#       dtype='|S3'), array([ 51, 197, 215, 225]))
# 50 (array(['401'],
#       dtype='|S3'), array([50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0595
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([193, 219, 217]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0596
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([180, 190, 213]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0597
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([194, 223, 291]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0598
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([198, 202, 218]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0599
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([191, 191, 219]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0600
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([199, 210, 233]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0601
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([187, 201, 222]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0605
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([188, 218, 263]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0606
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([194, 222, 268]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0608
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([188, 204, 252]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0610
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 249, 246]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0611
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([190, 209, 246]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0612
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([190, 225, 278]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0613
# long (array(['1001', '1101', '901'],
#       dtype='|S4'), array([219, 248, 196]))
# 50 (array(['701', '801'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['601'],
#       dtype='|S3'), array([100]))
# ********************
# 0614
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([207, 218, 280]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0627
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 207, 224]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0636
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([196, 225, 274]))
# 50 (array(['301', '401', '501'],
#       dtype='|S3'), array([50,  1, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0633
# long (array(['501', '601'],
#       dtype='|S3'), array([196, 220]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0628
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([210, 223, 257]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0620
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([185, 185, 211]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0624
# long (array(['1001', '1101', '1201', '1401', '801', '901'],
#       dtype='|S4'), array([ 85, 200, 221, 223, 178, 192]))
# 50 (array(['301', '601', '701'],
#       dtype='|S3'), array([50, 50, 50]))
# 100 (array(['201', '401', '501'],
#       dtype='|S3'), array([100,   1, 100]))
# ********************
# 0640
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([185, 220, 240]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['401'],
#       dtype='|S3'), array([100]))
# ********************
# 0639
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([225, 259, 255]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0650
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 205, 222]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0626
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 208, 228]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0632
# long (array(['601', '801', '901'],
#       dtype='|S3'), array([210, 239, 251]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0652
# long (array(['1001', '801', '901'],
#       dtype='|S4'), array([231, 192, 218]))
# 50 (array(['301', '401', '601', '701'],
#       dtype='|S3'), array([50, 50, 50, 50]))
# 100 (array(['201', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0634
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([200, 214, 239]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0630
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 209, 226]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0621
# long (array(['501', '601', '701', '801'],
#       dtype='|S3'), array([185,  39, 201, 203]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0625
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 204, 216]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0641
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([188, 215, 222]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0622
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([193, 213, 223]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0646
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([196, 207, 240]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0623
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([194, 212, 225]))
# 50 (array(['301', '501', '601'],
#       dtype='|S3'), array([34, 50, 50]))
# 100 (array(['201', '401'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0656
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([188, 220, 220]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0629
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 208, 227]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# none
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0635
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([195, 224, 285]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0642
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([193, 208, 214]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0638
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 200, 230]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0637
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([197, 220, 248]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0657
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([182, 198, 215]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0658
# long (array(['601', '701', '801', '901'],
#       dtype='|S3'), array([ 25, 181, 205, 221]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0643
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([219, 251, 267]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0645
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([197, 204, 236]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0651
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 228, 241]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0648
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([185, 206, 215]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0647
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([187, 217, 263]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0649
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([195, 217, 224]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0644
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([193, 244, 265]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0532 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([202, 204, 239]))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0537 wa
# long (array(['1001', '601', '701', '801', '901'],
#       dtype='|S4'), array([237,  26,  91, 201, 202]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0541 wa
# long (array(['1101', '1201', '1301'],
#       dtype='|S4'), array([201, 226, 267]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0543 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([198, 247, 294]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0544 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([209, 226, 249]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0547 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([199, 206, 233]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0548 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([241, 231, 281]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0549 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([185, 190, 225]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0550 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([232, 245, 348]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0551 wa
# long (array(['1001', '801', '901'],
#       dtype='|S4'), array([247, 192, 220]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0552 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 219, 275]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0553 wa
# long (array(['301', '401', '501', '601', '701', '801'],
#       dtype='|S3'), array([100,  50,  50, 230, 236, 268]))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0554 wa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([216, 225, 262]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['401'],
#       dtype='|S3'), array([100]))
# ********************
# 0555 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([200, 219, 240]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0556 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([212, 216, 255]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0557 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 233, 259]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0559 wa
# long (array(['601', '801', '901'],
#       dtype='|S3'), array([192, 204, 234]))
# 50 (array(['401'],
#       dtype='|S3'), array([50]))
# 100 (array(['301', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0560 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([225, 272, 316]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0563 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 205, 236]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0567 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([199, 202, 212]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0586 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([195, 203, 242]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0589 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 204, 235]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0590 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([194, 210, 233]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0591 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([207, 210, 234]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0592 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([212, 213, 240]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0593 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([188, 209, 228]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0594 wa
# long (array(['501', '601', '701', '801'],
#       dtype='|S3'), array([ 50, 196, 214, 224]))
# 50 (array(['401'],
#       dtype='|S3'), array([50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0595 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([192, 218, 216]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0596 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([179, 189, 212]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0597 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([193, 222, 290]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0598 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([197, 201, 217]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0599 wa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([190, 190, 218]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0600 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([198, 209, 232]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0601 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([186, 200, 221]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0605 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([187, 217, 262]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0606 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([193, 221, 267]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0608 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([187, 203, 251]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0610 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([205, 248, 245]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0611 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 208, 245]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0612 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 224, 277]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0613 wa
# long (array(['1001', '1101', '901'],
#       dtype='|S4'), array([218, 247, 195]))
# 50 (array(['701', '801'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['601'],
#       dtype='|S3'), array([100]))
# ********************
# 0614 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 217, 279]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0627 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 206, 223]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0636 wa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([195, 224, 273]))
# 50 (array(['301', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0633 wa
# long (array(['501', '601'],
#       dtype='|S3'), array([195,  77]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0628 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([209, 222, 256]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0620 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([184, 184, 210]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0624 wa
# long (array(['1001', '1101', '1201', '1401', '801', '901'],
#       dtype='|S4'), array([ 84, 199, 220, 222, 177, 191]))
# 50 (array(['301', '601', '701'],
#       dtype='|S3'), array([50, 50, 50]))
# 100 (array(['201', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0640 wa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([184, 219, 239]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['401'],
#       dtype='|S3'), array([100]))
# ********************
# 0639 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([224, 258, 254]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0650 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 204, 221]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0626 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 207, 227]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0632 wa
# long (array(['601', '801', '901'],
#       dtype='|S3'), array([209, 238, 250]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0652 wa
# long (array(['1001', '801', '901'],
#       dtype='|S4'), array([230, 191, 217]))
# 50 (array(['301', '401', '601', '701'],
#       dtype='|S3'), array([50, 50, 50, 50]))
# 100 (array(['201', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0634 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([199, 213, 238]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0630 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 208, 225]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0621 wa
# long (array(['501', '701', '801'],
#       dtype='|S3'), array([184, 200, 202]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0625 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([189, 203, 215]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0641 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([187, 214, 221]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0622 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 212, 222]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0646 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([195, 206, 239]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0623 wa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([193, 211, 224]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201', '401'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0656 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([187, 219, 219]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0629 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([189, 207, 226]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# none wa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0635 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([194, 223, 284]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0642 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 207, 213]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0638 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 199, 229]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0637 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([196, 219, 247]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0657 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([181, 197, 214]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0658 wa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([180, 204, 220]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0643 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([218, 250, 266]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0645 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([196, 203, 235]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0651 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 227, 240]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0648 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([184, 205, 214]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0647 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([186, 216, 262]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0649 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([194, 216, 223]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0644 wa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 243, 264]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0532 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([202, 204, 239]))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0537 swa
# long (array(['1001', '601', '701', '801', '901'],
#       dtype='|S4'), array([237,  26,  91, 201, 202]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0541 swa
# long (array(['1101', '1201', '1301'],
#       dtype='|S4'), array([201, 226, 267]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0543 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([198, 247, 294]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0544 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([209, 226, 249]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0547 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([199, 206, 233]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0548 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([241, 231, 281]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0549 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([185, 190, 225]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0550 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([232, 245, 348]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0551 swa
# long (array(['1001', '801', '901'],
#       dtype='|S4'), array([247, 192, 220]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0552 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 219, 275]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0553 swa
# long (array(['301', '401', '501', '601', '701', '801'],
#       dtype='|S3'), array([100,  50,  50, 230, 236, 268]))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0554 swa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([216, 225, 262]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['401'],
#       dtype='|S3'), array([100]))
# ********************
# 0555 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([200, 219, 240]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0556 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([212, 216, 255]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0557 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 233, 259]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0559 swa
# long (array(['601', '801', '901'],
#       dtype='|S3'), array([192, 204, 234]))
# 50 (array(['401'],
#       dtype='|S3'), array([50]))
# 100 (array(['301', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0560 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([225, 272, 316]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0563 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 205, 236]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0567 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([199, 202, 212]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0586 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([195, 203, 242]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0589 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 204, 235]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0590 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([194, 210, 233]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0591 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([207, 210, 234]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0592 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([212, 213, 240]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0593 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([188, 209, 228]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0594 swa
# long (array(['501', '601', '701', '801'],
#       dtype='|S3'), array([ 50, 196, 214, 224]))
# 50 (array(['401'],
#       dtype='|S3'), array([50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0595 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([192, 218, 216]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0596 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([179, 189, 212]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0597 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([193, 222, 290]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0598 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([197, 201, 217]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0599 swa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([190, 190, 218]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0600 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([198, 209, 232]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0601 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([186, 200, 221]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0605 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([187, 217, 262]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0606 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([193, 221, 267]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0608 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([187, 203, 251]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0610 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([205, 248, 245]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0611 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 208, 245]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0612 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([189, 224, 277]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0613 swa
# long (array(['1001', '1101', '901'],
#       dtype='|S4'), array([218, 247, 195]))
# 50 (array(['701', '801'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['601'],
#       dtype='|S3'), array([100]))
# ********************
# 0614 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([206, 217, 279]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0627 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 206, 223]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0636 swa
# long (array(['601', '701', '801'],
#       dtype='|S3'), array([195, 224, 273]))
# 50 (array(['301', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0633 swa
# long (array(['501', '601'],
#       dtype='|S3'), array([195, 219]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0628 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([209, 222, 256]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0620 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([184, 184, 210]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0624 swa
# long (array(['1001', '1101', '1201', '1401', '801', '901'],
#       dtype='|S4'), array([ 84, 199, 220, 222, 177, 191]))
# 50 (array(['301', '601', '701'],
#       dtype='|S3'), array([50, 50, 50]))
# 100 (array(['201', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0640 swa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([184, 219, 239]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['401'],
#       dtype='|S3'), array([100]))
# ********************
# 0639 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([224, 258, 254]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0650 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 204, 221]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0626 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 207, 227]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0632 swa
# long (array(['601', '801', '901'],
#       dtype='|S3'), array([209, 238, 250]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0652 swa
# long (array(['1001', '801', '901'],
#       dtype='|S4'), array([230, 191, 217]))
# 50 (array(['301', '401', '601', '701'],
#       dtype='|S3'), array([50, 50, 50, 50]))
# 100 (array(['201', '501'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0634 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([199, 213, 238]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0630 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 208, 225]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0621 swa
# long (array(['501', '701', '801'],
#       dtype='|S3'), array([184, 200, 202]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0625 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([189, 203, 215]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0641 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([187, 214, 221]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0622 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 212, 222]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0646 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([195, 206, 239]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0623 swa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([193, 211, 224]))
# 50 (array(['501', '601'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201', '401'],
#       dtype='|S3'), array([100, 100]))
# ********************
# 0656 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([187, 219, 219]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0629 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([189, 207, 226]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# none swa
# long (array([], dtype=float64), array([], dtype=int64))
# 50 (array([], dtype=float64), array([], dtype=int64))
# 100 (array([], dtype=float64), array([], dtype=int64))
# ********************
# 0635 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([194, 223, 284]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0642 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 207, 213]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0638 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([191, 199, 229]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0637 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([196, 219, 247]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0657 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([181, 197, 214]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0658 swa
# long (array(['701', '801', '901'],
#       dtype='|S3'), array([180, 204, 220]))
# 50 (array(['401', '501'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['301'],
#       dtype='|S3'), array([100]))
# ********************
# 0643 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([218, 250, 266]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0645 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([196, 203, 235]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0651 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([190, 227, 240]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0648 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([184, 205, 214]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0647 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([186, 216, 262]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0649 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([194, 216, 223]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
# ********************
# 0644 swa
# long (array(['501', '601', '701'],
#       dtype='|S3'), array([192, 243, 264]))
# 50 (array(['301', '401'],
#       dtype='|S3'), array([50, 50]))
# 100 (array(['201'],
#       dtype='|S3'), array([100]))
